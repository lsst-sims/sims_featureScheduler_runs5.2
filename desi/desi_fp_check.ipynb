# %%
import matplotlib.pylab as plt
# %matplotlib inline 
from desi_fp import desi_footprint
import healpy as hp

# %%
desi_y4, desi_y2 = desi_footprint(nside=32)

# %%
hp.mollview(desi_y2)
#hp.graticule()

# %%
hp.mollview(desi_y4, title="desi_y4")

# %%
hp.mollview(desi_y2+desi_y4, title="desi sum")
